# %% [markdown]
# <a href="https://colab.research.google.com/github/k-anand-1702/2025-26-160724754096-K-Anand-AI-B-DS/blob/main/03_02_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = {1, 2, 3}
s.add(4)

d = {"a": 1, "b": 2}
d["c"] = 3

print(s)
print(d)

# %%
my_list = [10, 20, 30, 40]

my_list.append(50)
my_list.remove(20)
print(my_list)

# %%
t = (1, 2, 3)
print(t[0])
print(len(t))

# %%
s = {1, 2, 3, 4}

s.add(5)
s.update([6, 7])

s.remove(2)
s.discard(10)

a = {1, 2, 3}
b = {3, 4, 5}
print(a | b)
print(a & b)
print(a - b)

print(len(s))
print(3 in s)

# %%
d = {"name": "John", "age": 20}

# add / update
d["age"] = 21
d["city"] = "Delhi"
print(d["name"])
print(d.get("marks", "Not Found"))

# remove
del d["age"]
d.pop("city")

# loop
for key, value in d.items():
    print(key, ":", value)

print(d.keys())
print(d.values())
print(d.items())

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/dataprofessor/data/master/BostonHousing.csv"

df = pd.read_csv(url)
print(df.head())

df.to_csv("iris_dataset.csv", index=False)
